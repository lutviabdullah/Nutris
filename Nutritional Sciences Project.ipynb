# %%
import pandas as pd
import os

os.getcwd()
# Out:
# 'C:\\Users\\OS\\Documents\\Data Sciences Project'

# %%
pd.set_option('display.max_columns', None )


df = pd.read_csv('Protein_Supply_Quantity_Data.csv')

df.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan               0.0000           9.7523       0.0277
# 1              Albania               0.1840          27.7469       0.0711
# 2              Algeria               0.0323          13.8360       0.0054
# 3               Angola               0.6285          15.2311       0.0277
# 4  Antigua and Barbuda               0.1535          33.1901       0.1289
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                   35.9771  0.4067         0.0647
# 1                      0.0                   14.2331  1.8069         0.6274
# 2                      0.0                   26.5633  1.2916         0.6350
# 3                      0.0                   20.3882  0.1756         5.4436
# 4                      0.0                   10.5108  0.4850         8.2146
#
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Alcoholic Beverages', 'Animal Products', 'Animal fats',
#        'Aquatic Products, Other', 'Cereals - Excluding Beer', 'Eggs',
#        'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat',
#        'Milk - Excluding Butter', 'Offals', 'Oilcrops', 'Pulses', 'Spices',
#        'Starchy Roots', 'Stimulants', 'Sugar Crops', 'Sugar & Sweeteners',
#        'Treenuts', 'Vegetal Products', 'Vegetable Oils', 'Vegetables',
#        'Miscellaneous', 'Obesity', 'Undernourished', 'Confirmed', 'Deaths',
#        'Recovered', 'Active', 'Population', 'Unit (all except Population)'],
#       dtype='object')

# %%
df2 = df[['Animal Products', 'Animal fats', 'Cereals - Excluding Beer', 'Eggs',
       'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat',
       'Milk - Excluding Butter']]

df2.head()
# Out:
#    Animal Products  Animal fats  Cereals - Excluding Beer    Eggs  \
# 0           9.7523       0.0277                   35.9771  0.4067
# 1          27.7469       0.0711                   14.2331  1.8069
# 2          13.8360       0.0054                   26.5633  1.2916
# 3          15.2311       0.0277                   20.3882  0.1756
# 4          33.1901       0.1289                   10.5108  0.4850
#
#    Fish, Seafood  Fruits - Excluding Wine     Meat  Milk - Excluding Butter
# 0         0.0647                   0.5824   3.1337                   5.5278
# 1         0.6274                   1.2757   7.6582                  16.4750
# 2         0.6350                   1.1624   3.5088                   8.0616
# 3         5.4436                   1.2754   7.6248                   1.1460
# 4         8.2146                   1.2586  16.0670                   7.4349

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df2.plot()
# Out:
# <AxesSubplot:>

# %%
df2['Meat'].plot()
plt.ylabel('Meat for Food & Diet')
plt.grid()

# %%
plt.plot(df2)
